# %% [markdown]
# # Thompson Sampling

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Ads_CTR_Optimisation.csv')

# %% [markdown]
# ## Implementing Thompson Sampling

# %%
import random
N = 10000 # number of users
d = 10 # number of ads
ads_selected = []

#Step 1:
numbers_of_rewards_1 = [0] * d #Ni^1 (n)
numbers_of_rewards_0 = [0] * d #Ni^0 (n)
total_reward = 0
for n in range(0, N):
  ad = 0
#Step 2:
  max_random = 0 #random draw
  for i in range(0, d):
    random_beta = random.betavariate(numbers_of_rewards_1[i] + 1, numbers_of_rewards_0[i] + 1)
#Step 3:
    if (random_beta > max_random):
      max_random = random_beta
      ad = i
  ads_selected.append(ad)
  reward = dataset.values[n, ad]
  if reward == 1:
    numbers_of_rewards_1[ad] = numbers_of_rewards_1[ad] + 1
  else:
    numbers_of_rewards_0[ad] = numbers_of_rewards_0[ad] + 1
  total_reward = total_reward + reward

# %% [markdown]
# ## Visualising the results - Histogram

# %%
plt.hist(ads_selected)
plt.title('Histogram of ads selections')
plt.xlabel('Ads')
plt.ylabel('Number of times each ad was selected')
plt.show()

# %% [markdown]
# Thompson Sampling will beat the Upper Confidence Bound Algorithm

# %% [markdown]
# If we change N to 500 we will see that Thompson sampling algorithm's result
#
# is definitely better than Upper Confidence Bound algorithm's result
